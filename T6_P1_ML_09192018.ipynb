# %%
# Import Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

style.use('ggplot')

# %%
# Read CSV File 
# Cite Data Source""
file = "vgsales.csv"
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
#read the data frame
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
# Data Overview for any cleanup requirements
df.count()
# Out:
# Rank            16598
# Name            16598
# Platform        16598
# Year            16327
# Genre           16598
# Publisher       16540
# NA_Sales        16598
# EU_Sales        16598
# JP_Sales        16598
# Other_Sales     16598
# Global_Sales    16598
# dtype: int64

# %% [markdown]
# FINDINGS #1. Year column has 271 entries with N/A
#           #2. Publisher column has 58 entries with N/A

# %%
# Cleaned data set
df = df.dropna(how='any')
df.count()
# Out:
# Rank            16291
# Name            16291
# Platform        16291
# Year            16291
# Genre           16291
# Publisher       16291
# NA_Sales        16291
# EU_Sales        16291
# JP_Sales        16291
# Other_Sales     16291
# Global_Sales    16291
# dtype: int64

# %%
# Data types 
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
# statistical overview
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16291.000000  16291.000000  16291.000000  16291.000000  16291.000000
# mean    8290.190228   2006.405561      0.265647      0.147731      0.078833
# std     4792.654450      5.832412      0.822432      0.509303      0.311879
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4132.500000   2003.000000      0.000000      0.000000      0.000000
# 50%     8292.000000   2007.000000      0.080000      0.020000      0.000000
# 75%    12439.500000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16291.000000  16291.000000
# mean       0.048426      0.540910
# std        0.190083      1.567345
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.480000
# max       10.570000     82.740000

# %%
#count of uniques platforms
count_platforms = df["Platform"].value_counts()
count_platforms
# Out:
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# GC       542
# 3DS      499
# PSV      410
# PS4      336
# N64      316
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     116
# NES       98
# GB        97
# DC        52
# GEN       27
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: Platform, dtype: int64

# %%
#count by genres
count_genres = df["Genre"].value_counts()
count_genres
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %%
#count of uniques publishers
count_publisher = df["Publisher"].value_counts()
count_publisher
# Out:
# Electronic Arts                           1339
# Activision                                 966
# Namco Bandai Games                         928
# Ubisoft                                    918
# Konami Digital Entertainment               823
# THQ                                        712
# Nintendo                                   696
# Sony Computer Entertainment                682
# Sega                                       632
# Take-Two Interactive                       412
# Capcom                                     376
# Atari                                      347
# Tecmo Koei                                 338
# Square Enix                                231
# Warner Bros. Interactive Entertainment     217
# Disney Interactive Studios                 214
# Midway Games                               196
# Eidos Interactive                          196
# 505 Games                                  192
# Microsoft Game Studios                     189
# Acclaim Entertainment                      184
# D3Publisher                                183
# Vivendi Games                              161
# Codemasters                                150
# Idea Factory                               128
# Deep Silver                                121
# Nippon Ichi Software                       104
# Zoo Digital Publishing                     104
# Unknown                                    100
# Majesco Entertainment                       90
#                                           ...
# Piacci                                       1
# FunSoft                                      1
# Just Flight                                  1
# Inti Creates                                 1
# White Park Bay Software                      1
# Tetris Online                                1
# Media Entertainment                          1
# Mycom                                        1
# Team17 Software                              1
# Sony Music Entertainment                     1
# Commseed                                     1
# ASK                                          1
# Illusion Softworks                           1
# Wargaming.net                                1
# Giga                                         1
# Nippon Amuse                                 1
# Game Arts                                    1
# Fuji                                         1
# Nexon                                        1
# HAL Laboratory                               1
# Hearty Robin                                 1
# Quest                                        1
# Bomb                                         1
# Kids Station                                 1
# Mirai Shounen                                1
# Summitsoft                                   1
# BushiRoad                                    1
# Vap                                          1
# Phantom EFX                                  1
# Origin Systems                               1
# Name: Publisher, Length: 576, dtype: int64

# %%
# General Obervations
# sales for the regions 

average_sales_NA = df["NA_Sales"].mean()
average_sales_EU = df["EU_Sales"].mean()
average_sales_JP = df["JP_Sales"].mean()
average_sales_Oth = df["Other_Sales"].mean()
average_sales_Global = df["Global_Sales"].mean()

 
total_sales_NA = df["NA_Sales"].sum()
total_sales_EU = df["EU_Sales"].sum()
total_sales_JP = df["JP_Sales"].sum()
total_sales_Oth = df["Other_Sales"].sum()
total_sales_Global = df["Global_Sales"].sum()


number_sales=df["Global_Sales"].count()
item_count = len(df["Name"].unique())

# DataFrame to hold results
summary_table = pd.DataFrame({"Number of Unique Items": [item_count],
                              "Total Sales NA": [total_sales_NA],
                              "Total Sales EU": [total_sales_EU],
                              "Total Sales JP": [total_sales_JP],
                              "Total Sales Oth": [total_sales_Oth],
                              "Total Sales Global": [total_sales_Global],
                              "Average Sales NA": [average_sales_NA],
                              "Average Sales EU": [average_sales_EU],
                              "Average Sales JP": [average_sales_JP],
                              "Average Sales Oth": [average_sales_Oth],
                              "Average Sales Global": [average_sales_Global],
                              "Total Sales Number": [number_sales]})

 
summary_table = summary_table.round(2)

# Display the summary_table
summary_table
# Out:
#    Number of Unique Items  Total Sales NA  Total Sales EU  Total Sales JP  \
# 0                   11325         4327.65         2406.69         1284.27
#
#    Total Sales Oth  Total Sales Global  Average Sales NA  Average Sales EU  \
# 0           788.91             8811.97              0.27              0.15
#
#    Average Sales JP  Average Sales Oth  Average Sales Global  \
# 0              0.08               0.05                  0.54
#
#    Total Sales Number
# 0               16291

# %%
#sales share by region 
NA_per = total_sales_NA/total_sales_Global*100
EU_per = total_sales_EU/total_sales_Global*100  
JP_per = total_sales_JP/total_sales_Global*100  
oth_per = total_sales_Oth /total_sales_Global*100

Sales_dist_table = pd.DataFrame({"Percentage Sales NA": [NA_per],
                                 "Percentage Sales EU": [EU_per],
                                 "Percentage Sales JP": [JP_per],
                                 "Percentage Sales Oth": [oth_per]
                              })

 
Sales_dist_table = Sales_dist_table.round(2)

# Display the summary_table
Sales_dist_table
# Out:
#    Percentage Sales NA  Percentage Sales EU  Percentage Sales JP  \
# 0                49.11                27.31                14.57
#
#    Percentage Sales Oth
# 0                  8.95

# %% [markdown]
# Obervations
# 1. Total Sales are highest in NA followed by EU, JP and Others
# 2. We can make a pie chart of sales share

# %%
# Sales Trends by regions
by_year = df.groupby("Year")

sales_by_year = by_year["Global_Sales", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"].sum()
sales_by_year = pd.DataFrame(sales_by_year)
sales_by_year = sales_by_year.sort_values('Global_Sales',ascending = False) 
 

sales_by_year
# Out:
#         Global_Sales  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Year
# 2008.0        678.90    351.44    184.40     60.26        82.39
# 2009.0        667.30    338.85    191.59     61.89        74.77
# 2007.0        609.92    311.18    160.18     60.29        77.58
# 2010.0        600.29    304.24    176.57     59.49        59.90
# 2006.0        521.04    263.12    129.24     73.73        54.43
# 2011.0        515.80    241.00    167.31     53.04        54.39
# 2005.0        458.51    241.58    121.56     54.28        40.55
# 2004.0        414.01    218.80    105.92     41.65        47.24
# 2002.0        395.52    216.19    109.74     41.76        27.28
# 2013.0        368.11    154.77    125.80     47.59        39.82
# 2012.0        363.49    154.93    118.76     51.74        37.82
# 2003.0        357.85    193.59    103.81     34.20        26.01
# 2014.0        337.03    131.97    125.63     39.46        40.02
# 2001.0        331.47    173.98     94.89     39.86        22.76
# 2015.0        264.44    102.82     97.71     33.72        30.01
# 1998.0        256.47    128.36     66.90     50.04        11.03
# 1999.0        251.27    126.06     62.67     52.34        10.05
# 2000.0        201.56     94.49     52.75     42.77        11.62
# 1997.0        200.98     94.75     48.32     48.87         9.13
# 1996.0        199.15     86.76     47.26     57.44         7.69
# 1995.0         88.11     24.82     14.90     45.75         2.64
# 1994.0         79.17     28.15     14.88     33.99         2.20
# 1992.0         76.16     33.87     11.71     28.91         1.65
# 1989.0         73.45     45.15      8.44     18.36         1.50
# 2016.0         70.90     22.66     26.76     13.67         7.75
# 1985.0         53.94     33.73      4.74     14.56         0.92
# 1984.0         50.36     33.28      2.10     14.27         0.70
# 1990.0         49.39     25.46      7.63     14.88         1.40
# 1988.0         47.22     23.87      6.59     15.76         0.99
# 1993.0         45.98     15.12      4.65     25.33         0.89
# 1986.0         37.07     12.50      2.84     19.81         1.93
# 1981.0         35.77     33.40      1.96      0.00         0.32
# 1991.0         32.23     12.76      3.95     14.78         0.74
# 1982.0         28.86     26.92      1.65      0.00         0.31
# 1987.0         21.74      8.46      1.41     11.63         0.20
# 1983.0         16.79      7.76      0.80      8.10         0.14
# 1980.0         11.38     10.59      0.67      0.00         0.12
# 2020.0          0.29      0.27      0.00      0.00         0.02
# 2017.0          0.05      0.00      0.00      0.05         0.00

# %% [markdown]
# We can do a trend analysis (Line graph for regional sales) for each region

# %%
# Sales by publisher for regions
by_pub = df.groupby("Publisher")

sales_by_pub = by_pub["Global_Sales", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"].sum()

sales_by_pub = pd.DataFrame(sales_by_pub)
sales_by_pub = sales_by_pub.sort_values('Global_Sales',ascending = False)

sales_by_pub
# Out:
#                                         Global_Sales  NA_Sales  EU_Sales  \
# Publisher
# Nintendo                                     1784.43    815.75    418.30
# Electronic Arts                              1093.39    584.22    367.38
# Activision                                    721.41    426.01    213.72
# Sony Computer Entertainment                   607.28    265.22    187.55
# Ubisoft                                       473.54    252.81    163.03
# Take-Two Interactive                          399.30    220.47    117.95
# THQ                                           340.44    208.60     94.60
# Konami Digital Entertainment                  278.56     88.91     68.62
# Sega                                          270.70    108.78     81.41
# Namco Bandai Games                            253.65     69.38     42.61
# Microsoft Game Studios                        245.79    155.35     68.61
# Capcom                                        199.95     78.45     39.16
# Atari                                         146.77    101.23     25.80
# Square Enix                                   144.73     48.59     32.57
# Warner Bros. Interactive Entertainment        142.34     75.34     48.83
# Disney Interactive Studios                    118.76     70.44     34.36
# Eidos Interactive                              96.75     47.85     34.85
# LucasArts                                      84.95     48.43     26.00
# Bethesda Softworks                             81.53     39.43     30.48
# Midway Games                                   69.29     45.10     18.22
# Acclaim Entertainment                          64.14     42.75     16.75
# SquareSoft                                     57.65     11.06      4.95
# Vivendi Games                                  56.93     36.24     15.65
# 505 Games                                      55.91     31.83     16.43
# Tecmo Koei                                     53.55     14.08      7.08
# Codemasters                                    47.77     11.88     28.65
# Virgin Interactive                             43.87     18.99     12.94
# Enix Corporation                               33.74      0.76      0.31
# Deep Silver                                    25.59     12.73      8.89
# GT Interactive                                 25.23     15.57      8.49
# ...                                              ...       ...       ...
# Giga                                            0.02      0.00      0.00
# Revolution (Japan)                              0.02      0.00      0.00
# Plenty                                          0.02      0.00      0.00
# GOA                                             0.02      0.00      0.02
# Marvelous Games                                 0.02      0.00      0.00
# Technos Japan Corporation                       0.02      0.00      0.00
# RED Entertainment                               0.02      0.00      0.00
# Quintet                                         0.02      0.00      0.00
# Masque Publishing                               0.02      0.01      0.00
# Media Entertainment                             0.01      0.00      0.00
# Interworks Unlimited, Inc.                      0.01      0.01      0.00
# Ongakukan                                       0.01      0.00      0.00
# Interchannel-Holon                              0.01      0.00      0.00
# Inti Creates                                    0.01      0.00      0.00
# Otomate                                         0.01      0.00      0.00
# Michaelsoft                                     0.01      0.00      0.00
# UIG Entertainment                               0.01      0.00      0.01
# Stainless Games                                 0.01      0.01      0.01
# EON Digital Entertainment                       0.01      0.01      0.00
# Boost On                                        0.01      0.00      0.00
# New World Computing                             0.01      0.01      0.00
# Takuyo                                          0.01      0.00      0.00
# Naxat Soft                                      0.01      0.00      0.00
# Piacci                                          0.01      0.00      0.00
# Genterprise                                     0.01      0.00      0.00
# Epic Games                                      0.01      0.01      0.00
# Paradox Development                             0.01      0.00      0.01
# Rain Games                                      0.01      0.00      0.01
# Ascaron Entertainment                           0.01      0.00      0.01
# Commseed                                        0.01      0.00      0.00
#
#                                         JP_Sales  Other_Sales
# Publisher
# Nintendo                                  454.99        95.19
# Electronic Arts                            13.98       127.63
# Activision                                  6.54        74.79
# Sony Computer Entertainment                74.10        80.40
# Ubisoft                                     7.33        50.16
# Take-Two Interactive                        5.83        55.20
# THQ                                         5.01        32.11
# Konami Digital Entertainment               90.93        29.91
# Sega                                       56.19        24.30
# Namco Bandai Games                        126.84        14.64
# Microsoft Game Studios                      3.26        18.56
# Capcom                                     67.38        14.82
# Atari                                      10.70         8.73
# Square Enix                                49.79        13.84
# Warner Bros. Interactive Entertainment      1.03        17.14
# Disney Interactive Studios                  0.56        13.15
# Eidos Interactive                           6.11         7.90
# LucasArts                                   0.20        10.28
# Bethesda Softworks                          1.44        10.10
# Midway Games                                0.12         5.69
# Acclaim Entertainment                       1.14         3.37
# SquareSoft                                 40.13         1.54
# Vivendi Games                               0.23         4.76
# 505 Games                                   2.05         5.44
# Tecmo Koei                                 29.21         3.18
# Codemasters                                 0.83         6.29
# Virgin Interactive                          8.94         3.03
# Enix Corporation                           32.40         0.27
# Deep Silver                                 1.09         2.87
# GT Interactive                              0.02         1.14
# ...                                          ...          ...
# Giga                                        0.02         0.00
# Revolution (Japan)                          0.02         0.00
# Plenty                                      0.02         0.00
# GOA                                         0.00         0.00
# Marvelous Games                             0.02         0.00
# Technos Japan Corporation                   0.02         0.00
# RED Entertainment                           0.02         0.00
# Quintet                                     0.02         0.00
# Masque Publishing                           0.00         0.00
# Media Entertainment                         0.01         0.00
# Interworks Unlimited, Inc.                  0.00         0.00
# Ongakukan                                   0.01         0.00
# Interchannel-Holon                          0.01         0.00
# Inti Creates                                0.01         0.00
# Otomate                                     0.01         0.00
# Michaelsoft                                 0.01         0.00
# UIG Entertainment                           0.00         0.00
# Stainless Games                             0.00         0.00
# EON Digital Entertainment                   0.00         0.00
# Boost On                                    0.01         0.00
# New World Computing                         0.00         0.00
# Takuyo                                      0.01         0.00
# Naxat Soft                                  0.01         0.00
# Piacci                                      0.01         0.00
# Genterprise                                 0.01         0.00
# Epic Games                                  0.00         0.00
# Paradox Development                         0.00         0.00
# Rain Games                                  0.00         0.00
# Ascaron Entertainment                       0.00         0.00
# Commseed                                    0.01         0.00
#
# [576 rows x 5 columns]

# %% [markdown]
# We can have a analysis by region for the publisher type (top 5 or top 10)

# %%
# Sales by Genre for regions
by_genre = df.groupby("Genre")

sales_by_genre = by_genre["Global_Sales", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales" ].sum()

sales_by_genre = pd.DataFrame(sales_by_genre)

sales_by_genre = sales_by_genre.sort_values('Global_Sales',ascending = False)
# Out:
#               Global_Sales  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Genre
# Action             1722.84    861.77    516.48    158.65       184.92
# Sports             1309.24    670.09    371.34    134.76       132.65
# Shooter            1026.20    575.16    310.45     38.18       101.90
# Role-Playing        923.83    326.50    187.57    350.29        59.38
# Platform            829.13    445.99    200.65    130.65        51.51
# Misc                789.87    396.92    211.77    106.67        73.92
# Racing              726.76    356.93    236.31     56.61        76.68
# Fighting            444.05    220.74    100.00     87.15        36.19
# Simulation          389.98    181.78    113.02     63.54        31.36
# Puzzle              242.21    122.01     50.52     56.68        12.47
# Adventure           234.59    101.93     63.74     51.99        16.70
# Strategy            173.27     67.83     44.84     49.10        11.23

# %%
# Sales by Platform for regions
by_platform = df.groupby("Platform")

sales_by_platform = by_platform["Global_Sales", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales" ].sum()

sales_by_platform = pd.DataFrame(sales_by_platform)

sales_by_platform = sales_by_platform.sort_values('Global_Sales',ascending = False)

sales_by_platform
# Out:
#           Global_Sales  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# Platform
# PS2            1233.46    572.92    332.63    137.54       190.47
# X360            969.60    594.33    278.00     12.30        84.67
# PS3             949.35    388.90    340.47     79.21       140.81
# Wii             909.81    497.37    264.35     68.28        79.20
# DS              818.91    388.53    194.05    175.02        60.29
# PS              727.39    334.71    212.38    139.78        40.69
# GBA             305.62    178.43     72.49     46.56         7.51
# PSP             291.71    107.09     67.16     75.89        41.52
# PS4             278.10     96.80    123.70     14.30        43.36
# PC              254.70     92.04    137.35      0.17        24.33
# GB              254.42    113.64     47.51     85.12         8.16
# XB              252.09    182.06     59.65      1.38         8.48
# NES             251.07    125.94     21.15     98.65         5.31
# 3DS             246.27     78.03     58.29     97.30        12.55
# N64             218.21    138.91     41.03     33.76         4.31
# SNES            200.05     61.23     19.04    116.55         3.22
# GC              197.14    131.94     38.32     21.34         5.13
# XOne            141.06     83.19     45.65      0.34        11.92
# 2600             86.57     80.78      4.86      0.00         0.84
# WiiU             81.86     38.32     24.23     12.79         6.45
# PSV              61.60     16.07     16.27     20.86         8.41
# SAT              33.59      0.72      0.54     32.26         0.07
# GEN              28.36     19.27      5.52      2.67         0.89
# DC               15.97      5.43      1.69      8.56         0.27
# SCD               1.87      1.00      0.36      0.45         0.05
# NG                1.44      0.00      0.00      1.44         0.00
# WS                1.42      0.00      0.00      1.42         0.00
# TG16              0.16      0.00      0.00      0.16         0.00
# 3DO               0.10      0.00      0.00      0.10         0.00
# GG                0.04      0.00      0.00      0.04         0.00
# PCFX              0.03      0.00      0.00      0.03         0.00

# %%
# Sales by Name for regions
by_name = df.groupby("Name")

sales_by_name = by_name["Global_Sales", "NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales" ].sum()

sales_by_name = pd.DataFrame(sales_by_name)

sales_by_name= sales_by_name.sort_values('Global_Sales',ascending = False)

# %%
Top25_name = sales_by_name.nlargest(25, 'Global_Sales')
Top25_name['OtherCountries'] = Top25_name['Global_Sales'] - Top25_name['NA_Sales']

print(Top25_name)
# Out:
#                                 Global_Sales  NA_Sales  EU_Sales  JP_Sales  \
# Name
# Wii Sports                             82.74     41.49     29.02      3.77
# Grand Theft Auto V                     55.92     23.46     23.04      1.39
# Super Mario Bros.                      45.31     32.48      4.88      6.96
# Tetris                                 35.84     26.17      2.95      6.03
# Mario Kart Wii                         35.82     15.85     12.88      3.79
# Wii Sports Resort                      33.00     15.75     11.01      3.28
# Pokemon Red/Pokemon Blue               31.37     11.27      8.89     10.22
# Call of Duty: Modern Warfare 3         30.83     15.58     11.29      0.62
# New Super Mario Bros.                  30.01     11.38      9.23      6.50
# Call of Duty: Black Ops II             29.72     14.08     11.05      0.72
# Call of Duty: Black Ops                29.40     17.01      8.69      0.59
# Wii Play                               29.02     14.03      9.20      2.93
# New Super Mario Bros. Wii              28.62     14.59      7.06      4.70
# Duck Hunt                              28.31     26.93      0.63      0.28
# Call of Duty: Ghosts                   27.38     14.92      9.05      0.48
# Super Mario World                      26.07     15.99      4.86      4.49
# Call of Duty: Black Ops 3              25.32     11.89      9.56      0.43
# Call of Duty: Modern Warfare 2         25.09     13.52      8.11      0.46
# Nintendogs                             24.76      9.07     11.00      1.93
# Grand Theft Auto: San Andreas          23.86     10.77      1.96      0.41
# Minecraft                              23.73     10.82      8.85      1.15
# Mario Kart DS                          23.42      9.81      7.57      4.13
# Pokemon Gold/Pokemon Silver            23.10      9.00      6.18      7.20
# Wii Fit                                22.72      8.94      8.03      3.60
# Super Mario Bros. 3                    22.48     12.47      4.69      4.67
#
#                                 Other_Sales  OtherCountries
# Name
# Wii Sports                             8.46           41.25
# Grand Theft Auto V                     8.03           32.46
# Super Mario Bros.                      0.99           12.83
# Tetris                                 0.69            9.67
# Mario Kart Wii                         3.31           19.97
# Wii Sports Resort                      2.96           17.25
# Pokemon Red/Pokemon Blue               1.00           20.10
# Call of Duty: Modern Warfare 3         3.35           15.25
# New Super Mario Bros.                  2.90           18.63
# Call of Duty: Black Ops II             3.88           15.64
# Call of Duty: Black Ops                3.12           12.39
# Wii Play                               2.85           14.99
# New Super Mario Bros. Wii              2.26           14.03
# Duck Hunt                              0.47            1.38
# Call of Duty: Ghosts                   2.92           12.46
# Super Mario World                      0.75           10.08
# Call of Duty: Black Ops 3              3.42           13.43
# Call of Duty: Modern Warfare 2         3.01           11.57
# Nintendogs                             2.75           15.69
# Grand Theft Auto: San Andreas         10.72           13.09
# Minecraft                              2.93           12.91
# Mario Kart DS                          1.92           13.61
# Pokemon Gold/Pokemon Silver            0.71           14.10
# Wii Fit                                2.15           13.78
# Super Mario Bros. 3                    0.66           10.01

# %%
Top25_platform = sales_by_platform.nlargest(25,'Global_Sales')
Top25_platform['OtherCountries'] = Top25_platform['Global_Sales'] - Top25_platform['NA_Sales']

print(Top25_platform)
# Out:
#           Global_Sales  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Platform
# PS2            1233.46    572.92    332.63    137.54       190.47
# X360            969.60    594.33    278.00     12.30        84.67
# PS3             949.35    388.90    340.47     79.21       140.81
# Wii             909.81    497.37    264.35     68.28        79.20
# DS              818.91    388.53    194.05    175.02        60.29
# PS              727.39    334.71    212.38    139.78        40.69
# GBA             305.62    178.43     72.49     46.56         7.51
# PSP             291.71    107.09     67.16     75.89        41.52
# PS4             278.10     96.80    123.70     14.30        43.36
# PC              254.70     92.04    137.35      0.17        24.33
# GB              254.42    113.64     47.51     85.12         8.16
# XB              252.09    182.06     59.65      1.38         8.48
# NES             251.07    125.94     21.15     98.65         5.31
# 3DS             246.27     78.03     58.29     97.30        12.55
# N64             218.21    138.91     41.03     33.76         4.31
# SNES            200.05     61.23     19.04    116.55         3.22
# GC              197.14    131.94     38.32     21.34         5.13
# XOne            141.06     83.19     45.65      0.34        11.92
# 2600             86.57     80.78      4.86      0.00         0.84
# WiiU             81.86     38.32     24.23     12.79         6.45
# PSV              61.60     16.07     16.27     20.86         8.41
# SAT              33.59      0.72      0.54     32.26         0.07
# GEN              28.36     19.27      5.52      2.67         0.89
# DC               15.97      5.43      1.69      8.56         0.27
# SCD               1.87      1.00      0.36      0.45         0.05
#
#           OtherCountries
# Platform
# PS2               660.54
# X360              375.27
# PS3               560.45
# Wii               412.44
# DS                430.38
# PS                392.68
# GBA               127.19
# PSP               184.62
# PS4               181.30
# PC                162.66
# GB                140.78
# XB                 70.03
# NES               125.13
# 3DS               168.24
# N64                79.30
# SNES              138.82
# GC                 65.20
# XOne               57.87
# 2600                5.79
# WiiU               43.54
# PSV                45.53
# SAT                32.87
# GEN                 9.09
# DC                 10.54
# SCD                 0.87

# %%
import scipy.stats as stats
critical_value = stats.chi2.ppf(q = 0.95, df = 24)
critical_value
# Out:
# 36.41502850180731

# %%
#let's look at differences by platform NA/US vs Rest of World 
stats.chisquare(Top25_name['OtherCountries'], Top25_name['NA_Sales'])
# Out:
# Power_divergenceResult(statistic=80.53219652703714, pvalue=5.0039770750226196e-08)

# %%
#let's look at differences by platform NA/US vs Rest of the world
stats.chisquare(Top25_platform['OtherCountries'], Top25_platform['NA_Sales'])
# Out:
# Power_divergenceResult(statistic=2312.864231274496, pvalue=0.0)

# %%
import statsmodels.api as sm

from statsmodels.formula.api import ols
from statsmodels.sandbox.regression.predstd import wls_prediction_std

#linear regression assumptions
#Linearity
#No multicollinearity (you cant use an equation to model
#other varoables perfectly or correlation cant be 1 or -1

#Zero conditional mean
#
sales_model = ols("NA_Sales ~ EU_Sales", data = sales_by_name).fit()



sales_model_summary = sales_model.summary()
sales_model_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               NA_Sales   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.616
# Method:                 Least Squares   F-statistic:                 1.817e+04
# Date:                Wed, 19 Sep 2018   Prob (F-statistic):               0.00
# Time:                        18:44:29   Log-Likelihood:                -12461.
# No. Observations:               11325   AIC:                         2.493e+04
# Df Residuals:                   11323   BIC:                         2.494e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1261      0.007     17.783      0.000       0.112       0.140
# EU_Sales       1.2047      0.009    134.805      0.000       1.187       1.222
# ==============================================================================
# Omnibus:                    19511.928   Durbin-Watson:                   1.605
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         84500656.304
# Skew:                          11.368   Prob(JB):                         0.00
# Kurtosis:                     425.560   Cond. No.                         1.43
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sales_model_2 = ols("NA_Sales ~ EU_Sales + JP_Sales", data = sales_by_name).fit()

sales_model_2_summary = sales_model_2.summary()
sales_model_2_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               NA_Sales   R-squared:                       0.633
# Model:                            OLS   Adj. R-squared:                  0.633
# Method:                 Least Squares   F-statistic:                     9758.
# Date:                Wed, 19 Sep 2018   Prob (F-statistic):               0.00
# Time:                        18:45:37   Log-Likelihood:                -12209.
# No. Observations:               11325   AIC:                         2.442e+04
# Df Residuals:                   11322   BIC:                         2.445e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0952      0.007     13.464      0.000       0.081       0.109
# EU_Sales       1.1261      0.009    119.786      0.000       1.108       1.144
# JP_Sales       0.4202      0.018     22.716      0.000       0.384       0.456
# ==============================================================================
# Omnibus:                    18662.374   Durbin-Watson:                   1.664
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         63687428.021
# Skew:                          10.371   Prob(JB):                         0.00
# Kurtosis:                     369.792   Cond. No.                         3.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sales_model_3 = ols("EU_Sales ~ NA_Sales", data = sales_by_name).fit()
sales_model_3_summary = sales_model_3.summary()
sales_model_3_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               EU_Sales   R-squared:                       0.616
# Model:                            OLS   Adj. R-squared:                  0.616
# Method:                 Least Squares   F-statistic:                 1.817e+04
# Date:                Wed, 19 Sep 2018   Prob (F-statistic):               0.00
# Time:                        18:53:02   Log-Likelihood:                -7609.3
# No. Observations:               11325   AIC:                         1.522e+04
# Df Residuals:                   11323   BIC:                         1.524e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0171      0.005      3.648      0.000       0.008       0.026
# NA_Sales       0.5114      0.004    134.805      0.000       0.504       0.519
# ==============================================================================
# Omnibus:                    10234.718   Durbin-Watson:                   1.738
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         26972600.891
# Skew:                           2.986   Prob(JB):                         0.00
# Kurtosis:                     242.008   Cond. No.                         1.47
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sales_model_name_all = ols("NA_Sales ~ EU_Sales + JP_Sales + Other_Sales", data = sales_by_name).fit()
sales_model_name_all_summary = sales_model_name_all.summary()
sales_model_name_all_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               NA_Sales   R-squared:                       0.650
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     6996.
# Date:                Wed, 19 Sep 2018   Prob (F-statistic):               0.00
# Time:                        19:42:24   Log-Likelihood:                -11944.
# No. Observations:               11325   AIC:                         2.390e+04
# Df Residuals:                   11321   BIC:                         2.392e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.0857      0.007     12.384      0.000       0.072       0.099
# EU_Sales        0.8325      0.016     53.370      0.000       0.802       0.863
# JP_Sales        0.4570      0.018     25.192      0.000       0.421       0.493
# Other_Sales     0.9720      0.042     23.280      0.000       0.890       1.054
# ==============================================================================
# Omnibus:                    19028.639   Durbin-Watson:                   1.661
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         72950676.415
# Skew:                          10.786   Prob(JB):                         0.00
# Kurtosis:                     395.597   Cond. No.                         7.17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# fig_name = plt.figure(figsize = (15,8))
# fig_name_plot = sm.graphics.plot_partregress_grid(sales_model_name_all, fig = fig_name)

# %%
#sales by genre model all variables

sales_model_genre = ols("NA_Sales ~ EU_Sales + JP_Sales + Other_Sales", data = sales_by_genre).fit()
#sales_model_2 = ols("NA_Sales ~ EU_Sales + ", data = sales_by_name).fit()
sales_model_genre.summary()
# Out:
# C:\Users\markl\Anaconda3\envs\PythonDev\lib\site-packages\scipy\stats\stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=12
#   "anyway, n=%i" % int(n))
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               NA_Sales   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     112.2
# Date:                Wed, 19 Sep 2018   Prob (F-statistic):           7.07e-07
# Time:                        19:36:15   Log-Likelihood:                -59.973
# No. Observations:                  12   AIC:                             127.9
# Df Residuals:                       8   BIC:                             129.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.3894     30.787     -0.013      0.990     -71.384      70.605
# EU_Sales        2.6579      0.877      3.029      0.016       0.635       4.681
# JP_Sales        0.0180      0.161      0.112      0.914      -0.352       0.388
# Other_Sales    -2.6460      2.374     -1.115      0.297      -8.120       2.828
# ==============================================================================
# Omnibus:                        0.841   Durbin-Watson:                   2.975
# Prob(Omnibus):                  0.657   Jarque-Bera (JB):                0.673
# Skew:                          -0.229   Prob(JB):                        0.714
# Kurtosis:                       1.934   Cond. No.                         677.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#running lm by platform

sales_model_platform = ols("NA_Sales ~ EU_Sales + JP_Sales + Other_Sales", data = sales_by_platform).fit()
#sales_model_2 = ols("NA_Sales ~ EU_Sales + ", data = sales_by_name).fit()
sales_model_platform.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               NA_Sales   R-squared:                       0.880
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     66.00
# Date:                Wed, 19 Sep 2018   Prob (F-statistic):           1.49e-12
# Time:                        19:37:16   Log-Likelihood:                -170.81
# No. Observations:                  31   AIC:                             349.6
# Df Residuals:                      27   BIC:                             355.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       9.5330     15.996      0.596      0.556     -23.289      42.355
# EU_Sales        1.6647      0.301      5.522      0.000       1.046       2.283
# JP_Sales        0.2962      0.270      1.095      0.283      -0.259       0.851
# Other_Sales    -0.4495      0.698     -0.644      0.525      -1.881       0.982
# ==============================================================================
# Omnibus:                        3.184   Durbin-Watson:                   2.195
# Prob(Omnibus):                  0.203   Jarque-Bera (JB):                1.970
# Skew:                          -0.241   Prob(JB):                        0.373
# Kurtosis:                       4.137   Cond. No.                         203.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
fig = plt.figure(figsize = (15,8))
fig = sm.graphics.plot_partregress_grid(sales_model_platform, fig = fig)


#It is clear from the plots below that the relationship between EU and NA sales is positive; Japan is neutral; Others is actually 
##Negative
